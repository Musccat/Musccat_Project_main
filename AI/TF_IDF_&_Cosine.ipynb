# %%
# 장학금 데이터
scholarships = [
    {"name": "한국장학재단 국가(Ⅰ,Ⅱ유형)", "criteria": "소득분위별 차등지급"},
    {"name": "한국장학재단 대통령과학", "criteria": "국내 고등학교 전학년 수학, 과학 성적이 우수한 이공계열 학생"},
    {"name": "한국장학재단 국가우수(이공계)", "criteria": "입학 성적 또는 재학 중 성적이 우수한 이공계열 학생"},
    {"name": "한국장학재단 인문100년", "criteria": "인문계열 및 사회계열 학과(부) 재학 중인 1학년 또는 3학년 학생"},
    {"name": "한국장학재단 예술체육비전", "criteria": "예술계열 및 체육계열 학과(부) 재학 중인 1학년 또는 3학년 학생"},
    {"name": "한국장학재단 희망사다리", "criteria": "졸업 후 중소기업 취업 또는 창업을 희망하는 3학년, 4학년 학생"},
    {"name": "한국장학재단 푸른등대 삼성기부", "criteria": "소득구간 3구간 이하인 사회적 배려계층 가정의 학생"},
    {"name": "한국장학재단 국가근로", "criteria": "직전학기 성적 1.35 이상이고 소득분위가 8분위 이하인 학부 재학생"},
    {"name": "DB김준기 문화재단", "criteria": "학점 3.5 이상의 소득분위 8분위 이하의 3학년 재학생"},
    {"name": "KT문화재단", "criteria": "컴퓨터공학 전자공학 전공의 정규등록 학생"},
    {"name": "TS문화재단", "criteria": "조형예술대학 디자인학부 1학년"},
    {"name": "가송재단", "criteria": "학점 3.5 이상인 가정형편이 어려운 학생"},
    {"name": "경방육영회", "criteria": "섬유예술전공인 2학년, 3학년 학생으로 직전 및 성적 3.5 이상인 학생"},
    {"name": "노엽문화재단", "criteria": "컴퓨터공학 2학년, 3학년 학생으로 직전 및 평점 3.2 이상인 학생"},
    {"name": "대림수암장학문화재단", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "대상문화재단", "criteria": "수학과, 정치외교학과 2학년 진학예정자로 성적이 우수하고 가계곤란한 학생"},
    {"name": "돈암장학회", "criteria": "2학년, 3학년 교육공학, 과학교육, 수학교육 전공인 학생으로 직전학기 3.30/4.30 이상인 학생"},
    {"name": "두을장학재단", "criteria": "성적 우수하고 차세대 여성지도자로 성장하고자 하는 학생"},
    {"name": "롯데장학재단", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "매원장학재단", "criteria": "전년도 평점 3.00/4.30 이상이고 잔여 정규학기가 2개 이상 남은 학생"},
    {"name": "목암과학장학재단", "criteria": "생명과학/생명공학/화학/제약 전공 학생으로 누계평점이 3.30/4.30 이상인 학생"},
    {"name": "박현주재단", "criteria": "교환학생 파견자격을 재학 중 최초로 획득한 자로서 직전 및 누계평점이 모두 3.1/4.3 이상인 학생"},
    {"name": "미래의동반자재단", "criteria": "학비 마련에 어려움을 겪고 있는 실업가정의 자녀 또는 소득분위 6분위 이하의 학생"},
    {"name": "미래인재육성재단", "criteria": "성적 3.6 이상(이공, 상경, 언론, 법학분야 우대)"},
    {"name": "서울장학재단", "criteria": "소득분위 0분위, 1분위, 2분위, 3분위, 4분위로 실납부금 50만원 이상"},
    {"name": "서울장학재단 청춘스타트", "criteria": "대학신입생으로 기초생활수급자, 차상위계층, 혹은 시설(보육원, 쉼터, 그룹홈)생활 학생으로서 주민센터 및 복지시설에서 증빙서류 발급이 가능한 자"},
    {"name": "성옥문화재단", "criteria": "전라남도 및 광주광역시 출신 학생으로 3학년, 4학년 진학예정이며 직전년도 평점 3.00/4.30이상인 학생"},
    {"name": "세아해암학술장학재단", "criteria": "3개학기 이상 잔여정규학기 남은 학생으로 직전 2개학기 평점 3.1 이상인 학생"},
    {"name": "송파재단", "criteria": "약학과 5학년 진학예정인 학생으로 직전 및 성적 3.40/4.30 이상인 학생"},
    {"name": "신라문화장학재단", "criteria": "성적이 우수한 1학년 학생"},
    {"name": "아산사회복지재단", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "앨트웰민초장학재단", "criteria": "1학년 학생으로서 평점이 3.7 이상이며 향후 공직, 언론 진출희망학생"},
    {"name": "연재장학재단", "criteria": "소비자학과 정규등록예정생으로 평점 3.00/4.30 이상인 학생"},
    {"name": "오뚜기함태호재단", "criteria": "식품공학, 식품영양학 3학년 진학예정인 학생"},
    {"name": "용운장학회", "criteria": "가정형편이 어렵고 성적이 우수한 학생"},
    {"name": "우덕재단", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "우월김활란장학회", "criteria": "북한이탈주민으로 성적이 우수하고 품행이 단정하며 가정형편이 어려운 학생"},
    {"name": "우정장학문화재단", "criteria": "가정형편이 어렵고 성적이 우수한 학생"},
    {"name": "운경재단", "criteria": "인문대 3학년 진학예정으로 직전 및 평점 3.3 이상이며 가정형편이 어려운 학생"},
    {"name": "월악장학문화재단", "criteria": "정규등록생으로 직전 및 평점 3.6 이상이며 가정형편이 어려운 학생"},
    {"name": "유정장학회", "criteria": "직전년도 평점 3.5 이상이며 잔여 정규학기가 2개 학기 이상인 학생으로 가정형편이 어려운 학생"},
    {"name": "유한재단", "criteria": "의대, 약대 소속의 성적이 우수하고 가계 곤란한 학생"},
    {"name": "윤송조창석문화재단", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "이랜드재단", "criteria": "패션디자인, 섬유예술, 의류학 전공으로 가정형편이 어려운 정규등록 대상 학생"},
    {"name": "인춘재단", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "일주학술문화재단", "criteria": "성적이 우수한 1학년 학생"},
    {"name": "정산장학재단", "criteria": "2학년, 3학년, 4학년 학생으로 성적이 우수한 이공계 또는 일반계 학생 중 가정형편이 어려운 학생"},
    {"name": "정수장학회", "criteria": "2학년, 3학년 진학예정으로 직전학기 및 평점 3.5 이상이고 학업석차가 10% 이내"},
    {"name": "종근당고촌재단", "criteria": "3학년 학기 진학예정인 약학과 학부 학생"},
    {"name": "천만장학회", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "청호불교문화원", "criteria": "가정형편이 어려운 불교학생회 소속 학생(우대)"},
    {"name": "한국대학봉사회", "criteria": "정규등록학생으로 성적이 우수하고 봉사심이 많은 학생"},
    {"name": "한국지도자육성장학재단", "criteria": "2개학기 이상 이수 학생으로 리더십과 봉사정신이 투철한 학생으로 평점 3.05/4.30 이상인 학생"},
    {"name": "해동과학문화재단", "criteria": "화학공학, 재료공학, 전자전기공학, 신소재공학 전공인 학생으로 2학기 학업을 연속적으로 할 수 있는 학생  소득분위 2분위 이내의 학생"},
    {"name": "현대차정몽구재단", "criteria": "성적 우수하고 가계 곤란한 학생"},
    {"name": "형애장학회", "criteria": "성적 우수하고 가계 곤란한 2학년 이상의 학생"},
    {"name": "홍산장학재단", "criteria": "이공계 및 의약학계열 학생으로 가정형편이 어렵고 성적이 우수한 학생"},
    {"name": "흥한재단", "criteria": "음악학부 1학년, 2학년 학생으로 성적이 우수하고 가계곤란한 학생"},
]

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 학생 정보
student_info = {
    "학년": "4학년",
    "전공": "컴퓨터공학",
    "성적": 4.2,
    "소득분위": 2,
    "기타": ["성적 우수", "가계 곤란", "이공계", "불교"] # 지역, 계열 등 강조하고 싶은 점 작성
}

# 코사인 유사도로 측정하지 못하는 부분을 추가 점수로 고려함
def check_criteria(criteria, student_info):
    # 장학금 조건과 학생 정보를 비교하여 점수 추가
    # 조건이 충족되면 점수 부여

    score = 0

    # 학년 조건 비교 (~학년 이상도 포함)
    if re.search(r'(\d+학년)', criteria):
        required_year = re.findall(r'(\d+학년)', criteria)
        if any(int(year[0]) <= int(student_info["학년"][0]) for year in required_year):
            score += 1

    # 전공 조건 비교
    if re.search(student_info["전공"], criteria):
        score += 1

    # 성적 조건 비교
    if re.search(r'성적 ([\d\.]+)', criteria):
        min_gpa = float(re.findall(r'성적 ([\d\.]+)', criteria)[0])
        if student_info["성적"] >= min_gpa:
            score += 1

    # 소득분위 조건 비교 (장학금 기준의 소득분위보다 낮은지 체크)
    if re.search(r'소득분위 (\d+)', criteria):
        max_income_bracket = int(re.findall(r'소득분위 (\d+)', criteria)[0])
        if student_info["소득분위"] <= max_income_bracket:
            score += 1

    # 성적 우수의 기준 제시하여 비교 (4.0 이상이면 우수하다고 판단)
    if "성적 우수" or "성적이 우수한"  in criteria and student_info["성적"] >= 4.0:
        score += 0.5

     # 가계곤란한 기준 제시하여 비교 (소득분위 4 이하인 경우 해당한다고 판단)
    if "가계 곤란한" or "가정형편이 어려운" or "가정형편이 어렵고" in criteria and student_info["소득분위"] <= 4:
        score += 0.5

    return score

# 사용자 프로필을 텍스트로 변환하는 함수
def student_info_to_text(info):
    return f"{info['학년']} {info['전공']} 성적 {info['성적']} {info['소득분위']} {' '.join(info['기타'])}"

# 학생 정보를 텍스트로 변환
student_text = student_info_to_text(student_info)

# 장학금 조건 텍스트로 변환
scholarship_texts = [scholarship["criteria"] for scholarship in scholarships]

# TF-IDF 벡터화
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([student_text] + scholarship_texts)

# 코사인 유사도 계산
cosine_similarities = cosine_similarity(vectors[0:1], vectors[1:]).flatten()

# 유사도와 추가 점수를 합산하여 최종 점수 계산
final_scores = []
for i, scholarship in enumerate(scholarships):
    criteria_score = check_criteria(scholarship['criteria'], student_info)
    final_score = cosine_similarities[i] + criteria_score  # 유사도 점수와 추가 점수를 합산
    final_scores.append((scholarship['name'], final_score, scholarship['criteria']))

# 최종 점수 순으로 정렬하여 추천
final_scores = sorted(final_scores, key=lambda x: x[1], reverse=True)

# 추천 장학금 목록 출력
print("추천 장학금 목록:")
for scholarship, score, criteria in final_scores[:5]:  # 상위 5개의 장학금 추천
    print(f"{scholarship} (점수: {score:.2f}) - 기준: {criteria}")
# Out:
# 추천 장학금 목록:
# 노엽문화재단 (점수: 3.16) - 기준: 컴퓨터공학 2학년, 3학년 학생으로 직전 및 평점 3.2 이상인 학생
# 경방육영회 (점수: 3.12) - 기준: 섬유예술전공인 2학년, 3학년 학생으로 직전 및 성적 3.5 이상인 학생
# DB김준기 문화재단 (점수: 3.00) - 기준: 학점 3.5 이상의 소득분위 8분위 이하의 3학년 재학생
# 정산장학재단 (점수: 2.22) - 기준: 2학년, 3학년, 4학년 학생으로 성적이 우수한 이공계 또는 일반계 학생 중 가정형편이 어려운 학생
# 형애장학회 (점수: 2.21) - 기준: 성적 우수하고 가계 곤란한 2학년 이상의 학생

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 학생 정보
student_info = {
    "학년": "1학년",
    "전공": "패션디자인",
    "성적": 4.0,
    "소득분위": 1,
    "기타": ["가정형편 어려움", "예술계열/예술대학","성적 우수"] # 지역, 계열 등 강조하고 싶은 점 작성
}

# 코사인 유사도로 측정하지 못하는 부분을 추가 점수로 고려함
def check_criteria(criteria, student_info):
    # 장학금 조건과 학생 정보를 비교하여 점수 추가
    # 조건이 충족되면 점수 부여

    score = 0

    # 학년 조건 비교 (~학년 이상도 포함)
    if re.search(r'(\d+학년)', criteria):
        required_year = re.findall(r'(\d+학년)', criteria)
        if any(int(year[0]) <= int(student_info["학년"][0]) for year in required_year):
            score += 1

    # 전공 조건 비교
    if re.search(student_info["전공"], criteria):
        score += 1

    # 성적 조건 비교
    if re.search(r'성적 ([\d\.]+)', criteria):
        min_gpa = float(re.findall(r'성적 ([\d\.]+)', criteria)[0])
        if student_info["성적"] >= min_gpa:
            score += 1

    # 소득분위 조건 비교 (장학금 기준의 소득분위보다 낮은지 체크)
    if re.search(r'소득분위 (\d+)', criteria):
        max_income_bracket = int(re.findall(r'소득분위 (\d+)', criteria)[0])
        if student_info["소득분위"] <= max_income_bracket:
            score += 1

    # 성적 우수의 기준 제시하여 비교 (4.0 이상이면 우수하다고 판단)
    if "성적 우수" or "성적이 우수한" in criteria and student_info["성적"] >= 4.0:
        score += 0.5

     # 가계곤란한 기준 제시하여 비교 (소득분위 4 이하인 경우 해당한다고 판단)
    if "가계 곤란한" or "가정형편이 어려운" or "가정형편이 어렵고" in criteria and student_info["소득분위"] <= 4:
        score += 0.5

    return score

# 사용자 프로필을 텍스트로 변환하는 함수
def student_info_to_text(info):
    return f"{info['학년']} {info['전공']} 성적 {info['성적']} {info['소득분위']} {' '.join(info['기타'])}"

# 학생 정보를 텍스트로 변환
student_text = student_info_to_text(student_info)

# 장학금 조건 텍스트로 변환
scholarship_texts = [scholarship["criteria"] for scholarship in scholarships]

# TF-IDF 벡터화
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([student_text] + scholarship_texts)

# 코사인 유사도 계산
cosine_similarities = cosine_similarity(vectors[0:1], vectors[1:]).flatten()

# 유사도와 추가 점수를 합산하여 최종 점수 계산
final_scores = []
for i, scholarship in enumerate(scholarships):
    criteria_score = check_criteria(scholarship['criteria'], student_info)
    final_score = cosine_similarities[i] + criteria_score  # 유사도 점수와 추가 점수를 합산
    final_scores.append((scholarship['name'], final_score, scholarship['criteria']))
    #print(i,  criteria_score,  cosine_similarities[i])
# 최종 점수 순으로 정렬하여 추천
final_scores = sorted(final_scores, key=lambda x: x[1], reverse=True)

# 추천 장학금 목록 출력
print("추천 장학금 목록:")
for scholarship, score, criteria in final_scores[:5]:  # 상위 5개의 장학금 추천
    print(f"{scholarship} (점수: {score:.2f}) - 기준: {criteria}")
# Out:
# 추천 장학금 목록:
# 한국장학재단 예술체육비전 (점수: 2.20) - 기준: 예술계열 및 체육계열 학과(부) 재학 중인 1학년 또는 3학년 학생
# 신라문화장학재단 (점수: 2.15) - 기준: 성적이 우수한 1학년 학생
# 일주학술문화재단 (점수: 2.15) - 기준: 성적이 우수한 1학년 학생
# 이랜드재단 (점수: 2.12) - 기준: 패션디자인, 섬유예술, 의류학 전공으로 가정형편이 어려운 정규등록 대상 학생
# 경방육영회 (점수: 2.11) - 기준: 섬유예술전공인 2학년, 3학년 학생으로 직전 및 성적 3.5 이상인 학생

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 학생 정보
student_info = {
    "학년": "3학년",
    "전공": "중어중문", # 전공 및 계열
    "성적": 3.6,  # 4.5 만점
    "소득분위": 4,
    "기타": ["인문계열/인문대","전라남도 거주"] # 지역, 계열 등 강조하고 싶은 점 작성
}

# 코사인 유사도로 측정하지 못하는 부분을 추가 점수로 고려함
def check_criteria(criteria, student_info):
    # 장학금 조건과 학생 정보를 비교하여 점수 추가
    # 조건이 충족되면 점수 부여

    score = 0

    # 학년 조건 비교 (~학년 이상도 포함)
    if re.search(r'(\d+학년)', criteria):
        required_year = re.findall(r'(\d+학년)', criteria)
        if any(int(year[0]) <= int(student_info["학년"][0]) for year in required_year):
            score += 1

    # 전공 조건 비교
    if re.search(student_info["전공"], criteria):
        score += 1

    # 성적 조건 비교
    if re.search(r'성적 ([\d\.]+)', criteria):
        min_gpa = float(re.findall(r'성적 ([\d\.]+)', criteria)[0])
        if student_info["성적"] >= min_gpa:
            score += 1

    # 소득분위 조건 비교 (장학금 기준의 소득분위보다 낮은지 체크)
    if re.search(r'소득분위 (\d+)', criteria):
        max_income_bracket = int(re.findall(r'소득분위 (\d+)', criteria)[0])
        if student_info["소득분위"] <= max_income_bracket:
            score += 1

    # 성적 우수의 기준 제시하여 비교 (4.0 이상이면 우수하다고 판단)
    if "성적 우수" or "성적이 우수한" in criteria and student_info["성적"] >= 4.0:
        score += 0.5

     # 가계곤란한 기준 제시하여 비교 (소득분위 4 이하인 경우 해당한다고 판단)
    if "가계 곤란한" or "가정형편이 어려운" or "가정형편이 어렵고" in criteria and student_info["소득분위"] <= 4:
        score += 0.5

    return score

# 사용자 프로필을 텍스트로 변환하는 함수
def student_info_to_text(info):
    return f"{info['학년']} {info['전공']} 성적 {info['성적']} {info['소득분위']} {' '.join(info['기타'])}"

# 학생 정보를 텍스트로 변환
student_text = student_info_to_text(student_info)

# 장학금 조건 텍스트로 변환
scholarship_texts = [scholarship["criteria"] for scholarship in scholarships]

# TF-IDF 벡터화
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([student_text] + scholarship_texts)

# 코사인 유사도 계산
cosine_similarities = cosine_similarity(vectors[0:1], vectors[1:]).flatten()

# 유사도와 추가 점수를 합산하여 최종 점수 계산
final_scores = []
for i, scholarship in enumerate(scholarships):
    criteria_score = check_criteria(scholarship['criteria'], student_info)
    final_score = cosine_similarities[i] + criteria_score  # 유사도 점수와 추가 점수를 합산
    final_scores.append((scholarship['name'], final_score, scholarship['criteria']))

# 최종 점수 순으로 정렬하여 추천
final_scores = sorted(final_scores, key=lambda x: x[1], reverse=True)

# 추천 장학금 목록 출력
print("추천 장학금 목록:")
for scholarship, score, criteria in final_scores[:5]:  # 상위 5개의 장학금 추천
    print(f"{scholarship} (점수: {score:.2f}) - 기준: {criteria}")
# Out:
# 추천 장학금 목록:
# 경방육영회 (점수: 3.14) - 기준: 섬유예술전공인 2학년, 3학년 학생으로 직전 및 성적 3.5 이상인 학생
# DB김준기 문화재단 (점수: 3.06) - 기준: 학점 3.5 이상의 소득분위 8분위 이하의 3학년 재학생
# 운경재단 (점수: 2.24) - 기준: 인문대 3학년 진학예정으로 직전 및 평점 3.3 이상이며 가정형편이 어려운 학생
# 한국장학재단 인문100년 (점수: 2.21) - 기준: 인문계열 및 사회계열 학과(부) 재학 중인 1학년 또는 3학년 학생
# 성옥문화재단 (점수: 2.17) - 기준: 전라남도 및 광주광역시 출신 학생으로 3학년, 4학년 진학예정이며 직전년도 평점 3.00/4.30이상인 학생
